# %%
from pylab import * 
from matplotlib.ticker import PercentFormatter
from matplotlib.ticker import FuncFormatter
plt.figure(figsize=(6, 4),dpi=300)
# epoch_num=50
# 创建两行四列的子图布局
fig, axes = plt.subplots(2, 4, figsize=(16, 8))
categories = ['Gowalla', 'Foursquare-NYC', 'Foursquare-TKY']
bar_width = 0.2  # 柱状图的宽度
indices = np.arange(0,len(categories),1.2)  # x轴上的位置

# hatch_par = ['/', '', '|', '-', '+', 'x', 'o', 'O', '.', '*']

recall_1_values_16 = [0.2111220472440945, 0.17457932692307693,0.12578125]
recall_1_values_32 = [0.21533587598425197, 0.19095552884615385,0.12117745535714286]
recall_1_values_64 = [0.21730437992125984, 0.1886268028846154, 0.12578125]
recall_1_values_128 = [0.2138902559055118, 0.18329326923076922, 0.12826450892857144]
recall_1_values_256 = [0.21001476377952755, 0.18840144230769232, 0.12114955357142858]

axes[0, 0].bar(indices, recall_1_values_16, width=bar_width, hatch='o', color='deepskyblue', label='MHSTPP-a@d=16')
axes[0, 0].bar(indices+ bar_width, recall_1_values_32, width=bar_width, hatch='/', color='green', label='MHSTPP-a@d=32')
axes[0, 0].bar(indices+ 2 * bar_width, recall_1_values_64, width=bar_width, hatch='-', color='red', label='MHSTPP-a@d=64')
axes[0, 0].bar(indices+ 3 * bar_width, recall_1_values_128, width=bar_width, hatch='*', color='m', label='MHSTPP-a@d=128')
axes[0, 0].bar(indices+ 4 * bar_width, recall_1_values_256, width=bar_width, hatch='x', color='b', label='MHSTPP-a@d=256')

# 设置x轴刻度标签
axes[0, 0].set_xticks(indices + 1.5 * bar_width, categories)
axes[0, 0].set_xticklabels(categories, fontdict={'fontsize': 5})
# # 设置y轴刻度标签为百分数形式
# plt.gca().yaxis.set_major_formatter(PercentFormatter(1))  # 1 表示最大值是1
# 设置纵坐标刻度标签为百分数形式
def percent_formatter(x, pos):
    return f'{x*100:.0f}'  # 将刻度值乘以100并格式化为百分数形式

for ax in axes.flat:
    ax.yaxis.set_major_formatter(FuncFormatter(percent_formatter)) 

# 添加标签和标题
axes[0, 0].set_xlabel('dataset')
axes[0, 0].set_ylabel('Recall@1(%)')


# ===
recall_5_values_16 = [0.4530327263779528,0.36861478365384615,0.316796875]
recall_5_values_32 = [0.48372908464566927,0.4393780048076923,0.29006696428571427]
recall_5_values_64 = [ 0.495724655511811, 0.44516225961538464, 0.316796875]
recall_5_values_128 = [0.4986158956692913, 0.45132211538461536,0.33097098214285714]
recall_5_values_256 = [0.49535556102362205, 0.45462740384615385,  0.29324776785714285 ]
axes[0, 1].bar(indices, recall_5_values_16, width=bar_width, hatch='o', color='deepskyblue', label='MHSTPP-a@d=16')
axes[0, 1].bar(indices+ bar_width, recall_5_values_32, width=bar_width, hatch='/', color='green', label='MHSTPP-a@d=32')
axes[0, 1].bar(indices+ 2 * bar_width, recall_5_values_64, width=bar_width, hatch='-', color='red', label='MHSTPP-a@d=64')
axes[0, 1].bar(indices+ 3 * bar_width, recall_5_values_128, width=bar_width, hatch='*', color='m', label='MHSTPP-a@d=128')
axes[0, 1].bar(indices+ 4 * bar_width, recall_5_values_256, width=bar_width, hatch='x', color='b', label='MHSTPP-a@d=256')

# 设置x轴刻度标签
axes[0, 1].set_xticks(indices + 1.5 * bar_width, categories)
axes[0, 1].set_xticklabels(categories, fontdict={'fontsize': 5})
# # 设置y轴刻度标签为百分数形式
# plt.gca().yaxis.set_major_formatter(PercentFormatter(1))  # 1 表示最大值是1
# # 设置纵坐标刻度标签为百分数形式
# def percent_formatter(x, pos):
#     return f'{x*100:.0f}'  # 将刻度值乘以100并格式化为百分数形式

# for ax in axes.flat:
#     ax.yaxis.set_major_formatter(FuncFormatter(percent_formatter)) 

# 添加标签和标题
axes[0, 1].set_xlabel('dataset')
axes[0, 1].set_ylabel('Recall@5(%)')

#=======
recall_10_values_16 = [0.5208230807086615,0.44959435096153844,0.40904017857142855]
recall_10_values_32 = [0.5565022145669292,0.5416165865384616,0.3756138392857143]
recall_10_values_64 = [ 0.5673597440944882, 0.5471003605769231, 0.40904017857142855]
recall_10_values_128 = [0.5674520177165354, 0.5617487980769231,0.4318917410714286]
recall_10_values_256 = [0.5580093503937008, 0.5642277644230769, 0.38175223214285714]
axes[0, 2].bar(indices, recall_10_values_16, width=bar_width, hatch='o', color='deepskyblue', label='MHSTPP-a@d=16')
axes[0, 2].bar(indices+ bar_width, recall_10_values_32, width=bar_width, hatch='/', color='green', label='MHSTPP-a@d=32')
axes[0, 2].bar(indices+ 2 * bar_width, recall_10_values_64, width=bar_width, hatch='-', color='red', label='MHSTPP-a@d=64')
axes[0, 2].bar(indices+ 3 * bar_width, recall_10_values_128, width=bar_width, hatch='*', color='m', label='MHSTPP-a@d=128')
axes[0, 2].bar(indices+ 4 * bar_width, recall_10_values_256, width=bar_width, hatch='x', color='b', label='MHSTPP-a@d=256')

# 设置x轴刻度标签
axes[0, 2].set_xticks(indices + 1.5 * bar_width, categories)
axes[0, 2].set_xticklabels(categories, fontdict={'fontsize': 5})
# # 设置y轴刻度标签为百分数形式
# plt.gca().yaxis.set_major_formatter(PercentFormatter(1))  # 1 表示最大值是1
# # 设置纵坐标刻度标签为百分数形式
# def percent_formatter(x, pos):
#     return f'{x*100:.0f}'  # 将刻度值乘以100并格式化为百分数形式

# for ax in axes.flat:
#     ax.yaxis.set_major_formatter(FuncFormatter(percent_formatter)) 

# 添加标签和标题
axes[0, 2].set_xlabel('dataset')
axes[0, 2].set_ylabel('Recall@10(%)')

#====
recall_20_values_16 = [0.5859375,0.5226111778846154,0.5063058035714286]
recall_20_values_32 = [0.6214013287401575,0.6199669471153846,0.46436941964285716]
recall_20_values_64 = [  0.6373954232283464, 0.6400240384615384, 0.5063058035714286]
recall_20_values_128 = [ 0.6369032972440944, 0.6446814903846154,0.5269252232142857]
recall_20_values_256 = [ 0.6343196358267716, 0.6512169471153846, 0.46919642857142857]
axes[0, 3].bar(indices, recall_20_values_16, width=bar_width, hatch='o', color='deepskyblue', label='MHSTPP-a@d=16')
axes[0, 3].bar(indices+ bar_width, recall_20_values_32, width=bar_width, hatch='/', color='green', label='MHSTPP-a@d=32')
axes[0, 3].bar(indices+ 2 * bar_width, recall_20_values_64, width=bar_width, hatch='-', color='red', label='MHSTPP-a@d=64')
axes[0, 3].bar(indices+ 3 * bar_width, recall_20_values_128, width=bar_width, hatch='*', color='m', label='MHSTPP-a@d=128')
axes[0, 3].bar(indices+ 4 * bar_width, recall_20_values_256, width=bar_width, hatch='x', color='b', label='MHSTPP-a@d=256')

# 设置x轴刻度标签
axes[0, 3].set_xticks(indices + 1.5 * bar_width, categories)
axes[0, 3].set_xticklabels(categories, fontdict={'fontsize': 5})
# # 设置y轴刻度标签为百分数形式
# plt.gca().yaxis.set_major_formatter(PercentFormatter(1))  # 1 表示最大值是1
# # 设置纵坐标刻度标签为百分数形式
# def percent_formatter(x, pos):
#     return f'{x*100:.0f}'  # 将刻度值乘以100并格式化为百分数形式

# for ax in axes.flat:
#     ax.yaxis.set_major_formatter(FuncFormatter(percent_formatter)) 

# 添加标签和标题
axes[0, 3].set_xlabel('dataset')
axes[0, 3].set_ylabel('Recall@20(%)')

#====
mrr_1_values_16 = [0.2111220472440945,  0.17457932692307693 ,0.12165178571428571]
mrr_1_values_32 = [0.21533587598425197, 0.19095552884615385,0.12117745535714286]
mrr_1_values_64 = [0.21730437992125984,  0.1886268028846154,  0.12578125]
mrr_1_values_128 = [0.2138902559055118, 0.18329326923076922, 0.12826450892857144]
mrr_1_values_256 = [0.21001476377952755, 0.18840144230769232, 0.12114955357142858]

axes[1, 0].bar(indices, mrr_1_values_16, width=bar_width, hatch='o', color='deepskyblue', label='MHSTPP-a@d=16')
axes[1, 0].bar(indices+ bar_width, mrr_1_values_32, width=bar_width, hatch='/', color='green', label='MHSTPP-a@d=32')
axes[1, 0].bar(indices+ 2 * bar_width, mrr_1_values_64, width=bar_width, hatch='-', color='red', label='MHSTPP-a@d=64')
axes[1, 0].bar(indices+ 3 * bar_width, mrr_1_values_128, width=bar_width, hatch='*', color='m', label='MHSTPP-a@d=128')
axes[1, 0].bar(indices+ 4 * bar_width, mrr_1_values_256, width=bar_width, hatch='x', color='b', label='MHSTPP-a@d=256')

# 设置x轴刻度标签
axes[1, 0].set_xticks(indices + 1.5 * bar_width, categories)
axes[1, 0].set_xticklabels(categories, fontdict={'fontsize': 5})
# # 设置y轴刻度标签为百分数形式
# plt.gca().yaxis.set_major_formatter(PercentFormatter(1))  # 1 表示最大值是1
# 设置纵坐标刻度标签为百分数形式
def percent_formatter(x, pos):
    return f'{x*100:.0f}'  # 将刻度值乘以100并格式化为百分数形式

for ax in axes.flat:
    ax.yaxis.set_major_formatter(FuncFormatter(percent_formatter)) 

# 添加标签和标题
axes[1, 0].set_xlabel('dataset')
axes[1, 0].set_ylabel('MRR@1(%)')

#====
mrr_5_values_16 = [0.30233606053149614 , 0.2445525340544873,0.1592982700892858]
mrr_5_values_32 = [0.31673946030183747, 0.27880859375,0.18173177083333333]
mrr_5_values_64 = [ 0.3228454109251969, 0.27767427884615387,0.1947828311011905]
mrr_5_values_128 = [0.32178323900918654, 0.2811448317307693, 0.20186337425595227]
mrr_5_values_256 = [0.3205354945866142, 0.27917042267628206, 0.18408807663690477]

axes[1, 1].bar(indices, mrr_5_values_16, width=bar_width, hatch='o', color='deepskyblue', label='MHSTPP-a@d=16')
axes[1, 1].bar(indices+ bar_width, mrr_5_values_32, width=bar_width, hatch='/', color='green', label='MHSTPP-a@d=32')
axes[1, 1].bar(indices+ 2 * bar_width, mrr_5_values_64, width=bar_width, hatch='-', color='red', label='MHSTPP-a@d=64')
axes[1, 1].bar(indices+ 3 * bar_width, mrr_5_values_128, width=bar_width, hatch='*', color='m', label='MHSTPP-a@d=128')
axes[1, 1].bar(indices+ 4 * bar_width, mrr_5_values_256, width=bar_width, hatch='x', color='b', label='MHSTPP-a@d=256')

# 设置x轴刻度标签
axes[1, 1].set_xticks(indices + 1.5 * bar_width, categories)
axes[1, 1].set_xticklabels(categories, fontdict={'fontsize': 5})
# # 设置y轴刻度标签为百分数形式
# plt.gca().yaxis.set_major_formatter(PercentFormatter(1))  # 1 表示最大值是1
# 设置纵坐标刻度标签为百分数形式
def percent_formatter(x, pos):
    return f'{x*100:.0f}'  # 将刻度值乘以100并格式化为百分数形式

for ax in axes.flat:
    ax.yaxis.set_major_formatter(FuncFormatter(percent_formatter)) 

# 添加标签和标题
axes[1, 1].set_xlabel('dataset')
axes[1, 1].set_ylabel('MRR@5(%)')

#====

mrr_10_values_16 = [ 0.3110727736181416, 0.25442985562614473,0.16741561924248868]
mrr_10_values_32 = [0.325226485361205, 0.2925538897951008,0.19316492612670072]
mrr_10_values_64 = [0.3317802681891327, 0.2907303471268316, 0.2072207053394275]
mrr_10_values_128 = [ 0.3311765716785402, 0.29543009887248173, 0.21343869579081626 ]
mrr_10_values_256 = [0.32875344927587197, 0.2947870163690477, 0.19598354901856588]

axes[1, 2].bar(indices, mrr_10_values_16, width=bar_width, hatch='o', color='deepskyblue', label='MHSTPP-a@d=16')
axes[1, 2].bar(indices+ bar_width, mrr_10_values_32, width=bar_width, hatch='/', color='green', label='MHSTPP-a@d=32')
axes[1, 2].bar(indices+ 2 * bar_width, mrr_10_values_64, width=bar_width, hatch='-', color='red', label='MHSTPP-a@d=64')
axes[1, 2].bar(indices+ 3 * bar_width, mrr_10_values_128, width=bar_width, hatch='*', color='m', label='MHSTPP-a@d=128')
axes[1, 2].bar(indices+ 4 * bar_width, mrr_10_values_256, width=bar_width, hatch='x', color='b', label='MHSTPP-a@d=256')


# 设置x轴刻度标签
axes[1, 2].set_xticks(indices + 1.5 * bar_width, categories)
axes[1, 2].set_xticklabels(categories, fontdict={'fontsize': 5})
# # 设置y轴刻度标签为百分数形式
# plt.gca().yaxis.set_major_formatter(PercentFormatter(1))  # 1 表示最大值是1
# 设置纵坐标刻度标签为百分数形式
def percent_formatter(x, pos):
    return f'{x*100:.0f}'  # 将刻度值乘以100并格式化为百分数形式

for ax in axes.flat:
    ax.yaxis.set_major_formatter(FuncFormatter(percent_formatter)) 

# 添加标签和标题
axes[1, 2].set_xlabel('dataset')
axes[1, 2].set_ylabel('MRR@10(%)')
#====
mrr_20_values_16 = [0.31548437591197376, 0.25940919810421686,0.17228056852257698]
mrr_20_values_32 = [0.3289822468177512,  0.297557225848252,0.19945510352276505]
mrr_20_values_64 = [0.33575413139566906, 0.2965698726689504, 0.2137355374341244]
mrr_20_values_128 = [0.3355479521479553, 0.30107288583092034, 0.2199514666249572]
mrr_20_values_256 = [0.333011155213503, 0.30071312529391175, 0.2020549491191955]

axes[1, 3].bar(indices, mrr_20_values_16, width=bar_width, hatch='o', color='deepskyblue', label='MHSTPP-a@d=16')
axes[1, 3].bar(indices+ bar_width, mrr_20_values_32, width=bar_width, hatch='/', color='green', label='MHSTPP-a@d=32')
axes[1, 3].bar(indices+ 2 * bar_width, mrr_20_values_64, width=bar_width, hatch='-', color='red', label='MHSTPP-a@d=64')
axes[1, 3].bar(indices+ 3 * bar_width, mrr_20_values_128, width=bar_width, hatch='*', color='m', label='MHSTPP-a@d=128')
axes[1, 3].bar(indices+ 4 * bar_width, mrr_20_values_256, width=bar_width, hatch='x', color='b', label='MHSTPP-a@d=256')

# 设置x轴刻度标签
axes[1, 3].set_xticks(indices + 1.5 * bar_width, categories)
axes[1, 3].set_xticklabels(categories, fontdict={'fontsize': 5})
# # 设置y轴刻度标签为百分数形式
# plt.gca().yaxis.set_major_formatter(PercentFormatter(1))  # 1 表示最大值是1
# 设置纵坐标刻度标签为百分数形式
def percent_formatter(x, pos):
    return f'{x*100:.0f}'  # 将刻度值乘以100并格式化为百分数形式

for ax in axes.flat:
    ax.yaxis.set_major_formatter(FuncFormatter(percent_formatter)) 

# 添加标签和标题
axes[1, 3].set_xlabel('dataset')
axes[1, 3].set_ylabel('MRR@20(%)')

for i in range(4):
    for j in  range(2):
        axes[j, i].grid(linestyle='--', linewidth=0.5, color='gray')



# 调整子图布局
# plt.tight_layout()

# 在整个大图的上方添加共用的图例标题
# fig.suptitle('Shared Legend Above the Whole Figure', fontsize=16)
# 在整个大图的上方添加共用的图例
legend = axes[0,0].legend(loc='upper center', bbox_to_anchor=(2.4, 1.25), ncol=5)
# plt.tight_layout()

# 添加图例
# plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=5)
# plt.subplots_adjust(wspace=0.4)  
# plt.bar_label(bar_0, labels=['MHSTPP-a@d=16','MHSTPP-a@d=32','MHSTPP-a@d=64','MHSTPP-a@d=128','MHSTPP-a@d=256'],label_type='center')
# 展示图表
# 保存图表为图片文件
plt.savefig('different_d.png', dpi=300, bbox_extra_artists=(legend,))
plt.show()
